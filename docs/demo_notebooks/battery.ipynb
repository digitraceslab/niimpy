# %% [markdown]
# # Demo notebook: Analysing battery data

# %% [markdown]
# ## Introduction
#
# In this notebook , we will extract battery data from the Aware platform and infer users' behavioral patterns from their interaction with the phone. The below functions will be described in this notebook:
#
# - `niimpy.preprocessing.battery.battery_shutdown_info`: returns the timestamp when the device is shutdown or rebooted
# - `niimpy.preprocessing.battery.battery_occurrences`: returns the number of battery samples within a time range
# - `niimpy.preprocessing.battery.battery_gaps`: returns the time gaps between two battery sample

# %% [markdown]
# ## Read data

# %%
import pandas as pd
import niimpy
import niimpy.preprocessing.battery as battery
from niimpy import config
import warnings
warnings.filterwarnings("ignore")

# %%
data = niimpy.read_csv(config.MULTIUSER_AWARE_BATTERY_PATH, tz='Europe/Helsinki')
data.shape
# Out:
# (505, 8)

# %%
data.head()
# Out:
#                                              user        device          time  \
# 2020-01-09 02:20:02.924999936+02:00  jd9INuQ5BBlW  3p83yASkOb_B  1.578529e+09
# 2020-01-09 02:21:30.405999872+02:00  jd9INuQ5BBlW  3p83yASkOb_B  1.578529e+09
# 2020-01-09 02:24:12.805999872+02:00  jd9INuQ5BBlW  3p83yASkOb_B  1.578529e+09
# 2020-01-09 02:35:38.561000192+02:00  jd9INuQ5BBlW  3p83yASkOb_B  1.578530e+09
# 2020-01-09 02:35:38.953000192+02:00  jd9INuQ5BBlW  3p83yASkOb_B  1.578530e+09
#
#                                      battery_level  battery_status  \
# 2020-01-09 02:20:02.924999936+02:00             74               3
# 2020-01-09 02:21:30.405999872+02:00             73               3
# 2020-01-09 02:24:12.805999872+02:00             72               3
# 2020-01-09 02:35:38.561000192+02:00             72               2
# 2020-01-09 02:35:38.953000192+02:00             72               2
#
#                                      battery_health  battery_adaptor  \
# 2020-01-09 02:20:02.924999936+02:00               2                0
# 2020-01-09 02:21:30.405999872+02:00               2                0
# 2020-01-09 02:24:12.805999872+02:00               2                0
# 2020-01-09 02:35:38.561000192+02:00               2                0
# 2020-01-09 02:35:38.953000192+02:00               2                2
#
#                                                                datetime
# 2020-01-09 02:20:02.924999936+02:00 2020-01-09 02:20:02.924999936+02:00
# 2020-01-09 02:21:30.405999872+02:00 2020-01-09 02:21:30.405999872+02:00
# 2020-01-09 02:24:12.805999872+02:00 2020-01-09 02:24:12.805999872+02:00
# 2020-01-09 02:35:38.561000192+02:00 2020-01-09 02:35:38.561000192+02:00
# 2020-01-09 02:35:38.953000192+02:00 2020-01-09 02:35:38.953000192+02:00

# %% [markdown]
# # Feature extraction
#
# The dataframe's index first needs to be sorted in ascending order to be compatible with the functions in this module.
#
# First, we can count the amount the battery samples every 10 minutes by using the `battery_occurences` function. This function requires the index to be sorted.

# %%
from datetime import datetime
data = data.sort_index()
battery.battery_occurrences(data, {})

# %% [markdown]
# The above dataframe gives the battery information of all users. You can also get the information for an individual by passing a filter dataframe.

# %%
f = niimpy.preprocessing.battery.battery_occurrences
individual_occurences = battery.extract_features_battery(data.query('user == "jd9INuQ5BBlW"'), feature_functions={f: {'hours':0,'minutes':10}})
individual_occurences.head()
# Out:
# <function battery_occurrences at 0x7fc89be1e310> {'hours': 0, 'minutes': 10}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 f = niimpy.preprocessing.battery.battery_occurrences
# ----> 2 individual_occurences = battery.extract_features_battery(data.query('user == "jd9INuQ5BBlW"'), feature_functions={f: {'hours':0,'minutes':10}})
#       3 individual_occurences.head()
#
# File ~/src/niimpy/niimpy/preprocessing/battery.py:487, in extract_features_battery(df, feature_functions)
#     485 computed_features = []
#     486 if feature_functions is None:
# --> 487     feature_functions = ALL_FEATURE_FUNCTIONS
#     488 for feature_function, kwargs in feature_functions.items():
#     489     print(feature_function, kwargs)
#
# TypeError: battery_occurrences() got an unexpected keyword argument 'hours'

# %% [markdown]
# Next, you can extract the gaps between two consecutive battery samples with the `battery_gaps` function.

# %%
f = niimpy.preprocessing.battery.battery_gaps
gaps = battery.battery_gaps(data)
gaps.head()[['user', 'device','delta']]
# Out:
#                                              user        device  \
# 2019-08-05 14:00:58.600000+03:00     iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 14:03:35.800000+03:00     iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 14:30:54.196000+03:00     iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 15:22:06.193000192+03:00  iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 16:21:29.716000+03:00     iGyXetHE3S8u  Cq9vueHh3zVs
#
#                                                         delta
# 2019-08-05 14:00:58.600000+03:00              0 days 00:00:00
# 2019-08-05 14:03:35.800000+03:00       0 days 00:02:37.200000
# 2019-08-05 14:30:54.196000+03:00       0 days 00:27:18.396000
# 2019-08-05 15:22:06.193000192+03:00 0 days 00:51:11.997000192
# 2019-08-05 16:21:29.716000+03:00    0 days 00:59:23.522999808

# %% [markdown]
# The most important piece of information is the  `delta` column, which gives the time gap between two battery samples.

# %% [markdown]
# Knowing when the phone is shutdown is essential if we want to infer the usage behaviour of the subjects. This can be done by calling the `shutdown_info` function. The function returns the timestamp when the phone is shut down or rebooted (e.g: battery_status = -1).

# %%
shutdown = battery.shutdown_info(data, feature_functions={'battery_column_name': 'battery_status'})
shutdown
# Out:
#                                              user        device          time  \
# 2019-08-07 10:37:11.308000+03:00     iGyXetHE3S8u  Cq9vueHh3zVs  1.565163e+09
# 2019-08-07 10:37:11.323000064+03:00  iGyXetHE3S8u  Cq9vueHh3zVs  1.565163e+09
#
#                                      battery_level  battery_status  \
# 2019-08-07 10:37:11.308000+03:00                 2              -1
# 2019-08-07 10:37:11.323000064+03:00              2              -1
#
#                                      battery_health  battery_adaptor  \
# 2019-08-07 10:37:11.308000+03:00                  2                0
# 2019-08-07 10:37:11.323000064+03:00               2                0
#
#                                                                datetime
# 2019-08-07 10:37:11.308000+03:00       2019-08-07 10:37:11.308000+03:00
# 2019-08-07 10:37:11.323000064+03:00 2019-08-07 10:37:11.323000064+03:00

# %% [markdown]
# ## Extracting featrues with the extract_features call

# %% [markdown]
# We have seen above how to extract battery features using `niimpy`. Sometimes, we need more than one features and it would be inconvenient to extract everything one by one. `niimpy` provides a `extract_featurea` call to allow you extracting all the features available and combining them into a single data frame. The extractable features must start with the prefix `battery_`.

# %%
# Start by defining the feature name
f0 = niimpy.preprocessing.battery.battery_occurrences
f1 = niimpy.preprocessing.battery.battery_gaps
f2 = niimpy.preprocessing.battery.battery_charge_discharge

# The extract_feature function requires a feature_functions parameter. 
# This parameter accepts a dictionary where the key is the feature name and value
# is a dictionary containing values passed to the function.
features = battery.extract_features_battery(data, feature_functions={f0: {'hours':0,'minutes':10},
                                                                     f1: {},
                                                                    f2: {}})
features.head()
# Out:
# <function battery_occurrences at 0x000002927B9FAD40> {'hours': 0, 'minutes': 10}
# <function battery_gaps at 0x000002927B9FADD0> {}
# <function battery_charge_discharge at 0x000002927B9FAE60> {}
#                                                              start  \
# 2019-08-05 14:00:58.600000+03:00  2019-08-05 14:00:58.600000+03:00
# 2019-08-05 14:03:35.800000+03:00                               NaN
# 2019-08-05 14:10:58.600000+03:00  2019-08-05 14:10:58.600000+03:00
# 2019-08-05 14:20:58.600000+03:00  2019-08-05 14:20:58.600000+03:00
# 2019-08-05 14:30:54.196000+03:00                               NaN
#
#                                                                end  \
# 2019-08-05 14:00:58.600000+03:00  2019-08-05 14:10:58.600000+03:00
# 2019-08-05 14:03:35.800000+03:00                               NaN
# 2019-08-05 14:10:58.600000+03:00  2019-08-05 14:20:58.600000+03:00
# 2019-08-05 14:20:58.600000+03:00  2019-08-05 14:30:58.600000+03:00
# 2019-08-05 14:30:54.196000+03:00                               NaN
#
#                                   occurrences          user        device  \
# 2019-08-05 14:00:58.600000+03:00          1.0  iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 14:03:35.800000+03:00          NaN  iGyXetHE3S8u  Cq9vueHh3zVs
# 2019-08-05 14:10:58.600000+03:00          0.0           NaN           NaN
# 2019-08-05 14:20:58.600000+03:00          1.0           NaN           NaN
# 2019-08-05 14:30:54.196000+03:00          NaN  iGyXetHE3S8u  Cq9vueHh3zVs
#
#                                           time battery_level battery_status  \
# 2019-08-05 14:00:58.600000+03:00  1.565003e+09          47.0            3.0
# 2019-08-05 14:03:35.800000+03:00  1.565003e+09          46.0            3.0
# 2019-08-05 14:10:58.600000+03:00           NaN           NaN            NaN
# 2019-08-05 14:20:58.600000+03:00           NaN           NaN            NaN
# 2019-08-05 14:30:54.196000+03:00  1.565005e+09          45.0            3.0
#
#                                  battery_health battery_adaptor  ...  \
# 2019-08-05 14:00:58.600000+03:00            2.0             0.0  ...
# 2019-08-05 14:03:35.800000+03:00            2.0             0.0  ...
# 2019-08-05 14:10:58.600000+03:00            NaN             NaN  ...
# 2019-08-05 14:20:58.600000+03:00            NaN             NaN  ...
# 2019-08-05 14:30:54.196000+03:00            2.0             0.0  ...
#
#                                           time battery_level battery_status  \
# 2019-08-05 14:00:58.600000+03:00  1.565003e+09          47.0            3.0
# 2019-08-05 14:03:35.800000+03:00  1.565003e+09          46.0            3.0
# 2019-08-05 14:10:58.600000+03:00           NaN           NaN            NaN
# 2019-08-05 14:20:58.600000+03:00           NaN           NaN            NaN
# 2019-08-05 14:30:54.196000+03:00  1.565005e+09          45.0            3.0
#
#                                  battery_health battery_adaptor  \
# 2019-08-05 14:00:58.600000+03:00            2.0             0.0
# 2019-08-05 14:03:35.800000+03:00            2.0             0.0
# 2019-08-05 14:10:58.600000+03:00            NaN             NaN
# 2019-08-05 14:20:58.600000+03:00            NaN             NaN
# 2019-08-05 14:30:54.196000+03:00            2.0             0.0
#
#                                                          datetime  \
# 2019-08-05 14:00:58.600000+03:00 2019-08-05 14:00:58.600000+03:00
# 2019-08-05 14:03:35.800000+03:00 2019-08-05 14:03:35.800000+03:00
# 2019-08-05 14:10:58.600000+03:00                              NaT
# 2019-08-05 14:20:58.600000+03:00                              NaT
# 2019-08-05 14:30:54.196000+03:00 2019-08-05 14:30:54.196000+03:00
#
#                                                            tvalue  \
# 2019-08-05 14:00:58.600000+03:00 2019-08-05 14:00:58.600000+03:00
# 2019-08-05 14:03:35.800000+03:00 2019-08-05 14:03:35.800000+03:00
# 2019-08-05 14:10:58.600000+03:00                              NaT
# 2019-08-05 14:20:58.600000+03:00                              NaT
# 2019-08-05 14:30:54.196000+03:00 2019-08-05 14:30:54.196000+03:00
#
#                                                  tdelta  bdelta  \
# 2019-08-05 14:00:58.600000+03:00        0 days 00:00:00     0.0
# 2019-08-05 14:03:35.800000+03:00 0 days 00:02:37.200000    -1.0
# 2019-08-05 14:10:58.600000+03:00                    NaT     NaN
# 2019-08-05 14:20:58.600000+03:00                    NaT     NaN
# 2019-08-05 14:30:54.196000+03:00 0 days 00:27:18.396000    -1.0
#
#                                   charge/discharge
# 2019-08-05 14:00:58.600000+03:00               NaN
# 2019-08-05 14:03:35.800000+03:00         -0.006361
# 2019-08-05 14:10:58.600000+03:00               NaN
# 2019-08-05 14:20:58.600000+03:00               NaN
# 2019-08-05 14:30:54.196000+03:00         -0.000610
#
# [5 rows x 25 columns]
